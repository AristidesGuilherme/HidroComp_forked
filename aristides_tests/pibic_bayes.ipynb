# %% [markdown]
# ## Aplicação de inferência bayesiana nos parâmetros da distribuição GenPareto para magnitude de cheias

# %% [markdown]
# ### 1 - Preparando distribuição Generalizada de Pareto para utilizar no PyMC
